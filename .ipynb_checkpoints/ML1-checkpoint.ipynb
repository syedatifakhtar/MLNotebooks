# %%
from IPython.display import IFrame
IFrame("https://d3c33hcgiwev3.cloudfront.net/_974fa7509d583eabb592839f9716fe25_Lecture1.pdf?Expires=1516752000&Signature=TTh6Itd74RjpxiQw8W-oKVsabLcNsSKey1Vm7BWBO5CVUhqbDFuByZv31FP6IYnPwtrH0Q42TvYClCDwzJwDpoEEKWDNAMMzHEeIyQgt0VcwbTzpNhWaZ5S3lkWx1rwZooc6y3~uwgMKIN6LB~YUnIojmWIYi54EQyOAe15xfmE_&Key-Pair-Id=APKAJLTNE6QMUY6HBC5A", width=1000, height=600)
# Out:
#         <iframe
#             width="1000"
#             height="600"
#             src="https://d3c33hcgiwev3.cloudfront.net/_974fa7509d583eabb592839f9716fe25_Lecture1.pdf?Expires=1516752000&Signature=TTh6Itd74RjpxiQw8W-oKVsabLcNsSKey1Vm7BWBO5CVUhqbDFuByZv31FP6IYnPwtrH0Q42TvYClCDwzJwDpoEEKWDNAMMzHEeIyQgt0VcwbTzpNhWaZ5S3lkWx1rwZooc6y3~uwgMKIN6LB~YUnIojmWIYi54EQyOAe15xfmE_&Key-Pair-Id=APKAJLTNE6QMUY6HBC5A"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
from IPython.display import IFrame
IFrame("https://d3c33hcgiwev3.cloudfront.net/_ec21cea314b2ac7d9e627706501b5baa_Lecture2.pdf?Expires=1516752000&Signature=Dn69r36Cs3pluihlR0BnY-KLAYvX15emivjpXOT21pXmBvwvMRu6qt75FpIatV-TAqONKgL4Ooh6a6dkzmKnU-N6PGaNoyVUoRLovKKYm~-KxwgzvXT5KA9natAEG3zB2tZ741~NppZUPVw6K53UdgRBbKXTLYrf5MjUT9CpXL8_&Key-Pair-Id=APKAJLTNE6QMUY6HBC5A", width=800, height=600)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="https://d3c33hcgiwev3.cloudfront.net/_ec21cea314b2ac7d9e627706501b5baa_Lecture2.pdf?Expires=1516752000&Signature=Dn69r36Cs3pluihlR0BnY-KLAYvX15emivjpXOT21pXmBvwvMRu6qt75FpIatV-TAqONKgL4Ooh6a6dkzmKnU-N6PGaNoyVUoRLovKKYm~-KxwgzvXT5KA9natAEG3zB2tZ741~NppZUPVw6K53UdgRBbKXTLYrf5MjUT9CpXL8_&Key-Pair-Id=APKAJLTNE6QMUY6HBC5A"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
from __future__ import division
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
plt.rcParams['axes.formatter.limits'] = [-3,3]
plt.rcParams['font.size'] = 12
plt.rcParams['axes.labelsize'] = 12

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
data = np.loadtxt('/Users/syedatifakhtar/Downloads/machine_learning/machine-learning-ex1/ex1/ex1data1.txt', delimiter=',')
x, y = data[:,0], data[:,1]
m = len(y)

# %%
plt.plot(x, y, 'x', color='b')
plt.xlabel(r'Population of City in 10,000s')
plt.ylabel(r'Profit in $10,000s')
